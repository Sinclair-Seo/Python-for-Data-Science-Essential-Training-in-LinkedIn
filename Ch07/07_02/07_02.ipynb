# %% [markdown]
# ![title](Header__0003_7.png "Header")
# ___
# ## Chapter 7 - Network Analysis with NetworkX
# ##  Segment 2 - Working with graph objects

# %%
! pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\15\appdata\local\programs\python\python37-32\lib\site-packages (2.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\15\appdata\local\programs\python\python37-32\lib\site-packages (from networkx) (4.4.0)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

import networkx as nx

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %% [markdown]
# ### Creating graph objects

# %%
G = nx.Graph()
nx.draw(G)

# %%
G.add_node(1)
nx.draw(G)

# %%
G.add_nodes_from([2,3,4,5,6,8,9,12,15,16])
nx.draw(G)

# %%
G.add_edges_from([(2,4),(2,6),(2,8),(2,12),(2,16),(3,6),(3,9), (3,12),(3,15),(4,8),(4,12),(4,16),(6,12),(8,16)])
nx.draw(G)

# %% [markdown]
# ### The basics about drawing graph objects

# %%
nx.draw_circular(G)

# %%
nx.draw_spring(G)

# %% [markdown]
# ### Labeling and coloring your graph plots

# %%
nx.draw_circular(G, node_color='bisque', with_labels=True)

# %%
G.remove_node(4)
nx.draw_circular(G, node_color='bisque', with_labels=True)

# %% [markdown]
# ### Identifying graph properties

# %%
sum_stats = nx.info(G)
print(sum_stats)
# Out:
# Name:
# Type: Graph
# Number of nodes: 9
# Number of edges: 10
# Average degree:   2.2222

# %%
print(nx.degree(G))
# Out:
# [(2, 4), (3, 4), (5, 0), (6, 3), (8, 2), (9, 1), (12, 3), (15, 1), (16, 2)]

# %% [markdown]
# ### Using graph generators

# %%
G = nx.complete_graph(25)
nx.draw(G, node_color='bisque', with_labels=True)

# %%
G = nx.gnc_graph(7, seed=25)
nx.draw(G, node_color='bisque', with_labels=True)

# %%
ego_G = nx.ego_graph(G, 3, radius=5)
nx.draw(G, node_color='bisque', with_labels=True)
